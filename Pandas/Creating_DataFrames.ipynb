# %% [markdown]
# # Creating DataFrames in Pandas
#
# The **DataFrame** is the **core data structure** in Pandas — you'll use it in nearly every data science project.
# It represents **tabular data** (like an Excel sheet or SQL table) with rows and columns.
#
# ---
#
# ## 🧱 1. Creating a DataFrame from Python Lists
#
# You can create a DataFrame directly from a list of lists.
#
# ```python
# import pandas as pd
#
# data = [
#     ["Alice", 25],
#     ["Bob", 30],
#     ["Charlie", 35]
# ]
#
# df = pd.DataFrame(data, columns=["Name", "Age"])
# print(df)
# ```
# **Output:**
# ```
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# ```
#
# Each inner list becomes a row, and `columns` defines the column names.
#
# ---
#
# ## 🧾 2. Creating a DataFrame from a Dictionary of Lists
#
# This is the **most common and readable** way to create a DataFrame.
#
# ```python
# data = {
#     "Name": ["Alice", "Bob", "Charlie"],
#     "Age": [25, 30, 35]
# }
#
# df = pd.DataFrame(data)
# print(df)
# ```
# **Output:**
# ```
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# ```
#
# 👉 Each **key** becomes a column, and each **list** provides the column data.
#
# ---
#
# ## 🔢 3. Creating a DataFrame from NumPy Arrays
#
# You can convert a NumPy array into a DataFrame.
#
# ```python
# import numpy as np
#
# arr = np.array([[1, 2], [3, 4]])
# df = pd.DataFrame(arr, columns=["A", "B"])
# print(df)
# ```
# **Output:**
# ```
#    A  B
# 0  1  2
# 1  3  4
# ```
#
# ⚠️ Always provide **column names**, or Pandas will assign default integers.
#
# ---
#
# ## 📂 4. Creating a DataFrame from CSV Files
#
# You can load CSV files directly using:
#
# ```python
# df = pd.read_csv("data.csv")
# ```
#
# ### Useful options include:
# - `sep` → specify delimiter (e.g., comma, tab)
# - `header` → specify header row
# - `names` → custom column names
# - `index_col` → specify index column
# - `usecols` → select specific columns
# - `nrows` → read limited number of rows
#
# **Example:**
# ```python
# df = pd.read_csv("data.csv", usecols=["Name", "Age"])
# ```
#
# ---
#
# ## 📊 5. Creating a DataFrame from Excel Files
#
# You can read Excel files using:
#
# ```python
# df = pd.read_excel("data.xlsx")
# ```
#
# 📦 You might need to install additional libraries first:
#
# ```bash
# pip install openpyxl
# ```
# or
# ```bash
# pip install xlrd
# ```
#
# ---
#
# ## 🌐 6. Creating a DataFrame from JSON
#
# ```python
# df = pd.read_json("data.json")
# ```
# You can also read JSON directly from a **URL** or **string**.
#
# ---
#
# ## 🧠 7. Creating a DataFrame from SQL Databases
#
# You can read SQL query results directly into Pandas.
#
# ```python
# import sqlite3
#
# conn = sqlite3.connect("mydb.sqlite")
# df = pd.read_sql("SELECT * FROM users", conn)
# ```
#
# This allows direct integration with relational databases.
#
# ---
#
# ## 🌍 8. Creating a DataFrame from the Web
#
# You can even load datasets directly from online sources.
#
# ```python
# url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
# df = pd.read_csv(url)
# ```
#
# This is especially useful for fetching datasets for experiments and EDA.
#
# ---
#
# ## 🔍 EDA (Exploratory Data Analysis)
#
# Once your DataFrame is ready, it’s time to **explore your data**.
# EDA helps you understand structure, spot patterns, detect missing data, and prepare for modeling.
#
# ### Key Methods for EDA:
# ```python
# df.head()       # First 5 rows
# df.tail()       # Last 5 rows
# df.info()       # Column info: data types & null counts
# df.describe()   # Summary statistics for numeric columns
# df.columns      # List of column names
# df.shape        # (rows, columns)
# ```
#
# **Example:**
# ```python
# print(df.head())
# print(df.info())
# print(df.describe())
# ```
#
# 🧠 **EDA is essential** — it helps you understand the dataset **before** applying transformations or models.
#
# ---
#
# ## ✅ Summary
#
# - You can create DataFrames from **lists, dictionaries, NumPy arrays, CSV, Excel, JSON, web, and SQL sources**.
# - Use `.head()`, `.info()`, `.describe()` to quickly **explore and summarize** datasets.
# - The DataFrame is the **foundation of data analysis** in Pandas — master it early!

# %%
import numpy as np
import pandas as pd

# %%
data = [['Farhan', 76], ['Sam', 55]]                                  # Basic list of list

pd.DataFrame(data, columns = ['Names', 'Marks'])                      # Mannual columns name
# Out:
#     Names  Marks
# 0  Farhan     76
# 1     Sam     55

# %% [markdown]
# #### Using Dictionary

# %%
data1 = {
    "name": ['Farhan', 'Sam'],
    "marks": [33, 22]}

pd.DataFrame(data1)
# Out:
#      name  marks
# 0  Farhan     33
# 1     Sam     22

# %% [markdown]
# #### Using NumPy

# %%
arr = np.array([[1,2], [5,6]])

df = pd.DataFrame(arr, columns =['A', 'B'])
df
# Out:
#    A  B
# 0  1  2
# 1  5  6

# %% [markdown]
# #### Read Excel Files

# %%
dff = pd.read_excel('data.xlsx')
dff
# Out:
#      Name  School  Marks
# 0   Farhan     aa     45
# 1  Zeeshan     ff     76
# 2   Samiya     as     45
# 3      Fam    dwd     54

# %% [markdown]
# #### Read CSV Files
#
# dfff = pd.read_csv('data.csv')

# %% [markdown]
# #### Read Json File

# %%
pd.read_json('data.json')               # Ensure you json data enclose in []
# Out:
#    fruit   size color
# 0  Apple  Large   Red

# %% [markdown]
# #### From the Web (Example: CSV from URL)

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df2.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df2.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df2.shape
# Out:
# (244, 7)

# %%
import pandas as pd

# %%
data =
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
data = [
    ['Farhan',21],
    ['Samiya',22]
]
dff = pd.DataFrame(data, columns=['Name', 'Age'])

# %%
dff
# Out:
#      Name  Age
# 0  Farhan   21
# 1  Samiya   22

# %%
import numpy as np

# %%
arr = np.array([[1,2], [2,1]])

# %%
df1 = pd.DataFrame(arr, columns =["a", "v"])
df1
# Out:
#    a  v
# 0  1  2
# 1  2  1

# %%
dff.describe()
# Out:
#              Age
# count   2.000000
# mean   21.500000
# std     0.707107
# min    21.000000
# 25%    21.250000
# 50%    21.500000
# 75%    21.750000
# max    22.000000
