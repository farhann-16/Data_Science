# %%
import numpy as np

# %%
arr1 = np.array([1, 3, 6])
arr2 = np.array([2, 4, 7])

# %%
result = arr1 + arr2
result
# Out:
# array([ 3,  7, 13])

# %%
arr3 = np.array([[1, 3, 6], [2, 4, 7]])
arr3
# Out:
# array([[1, 3, 6],
#        [2, 4, 7]])

# %%
arr3.shape              # 2- Rows and 3- Columns
# Out:
# (2, 3)

# %%
arr3.nbytes
# Out:
# 48

# %%
arr1 = arr1 ** 2

# %% [raw]
# arr1
